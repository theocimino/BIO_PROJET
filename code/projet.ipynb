# %% [markdown]
# <H1 align="center">
# 📊 Dynamique des populations
# </H1>
# <div align="center">
#
# **Gagik Eknosyan & Théo Cimino**
# *2026 • MAM4 Maths-bio*
# </div>
#
# ---

# %% [markdown]
# [Énoncé (PDF)](../sujet.pdf)

# %% [markdown]
# On considère donc le modèle suivant : \
# \
# $\dot{P} = r(H)P - \delta P^2$ \
# $\dot{H} = \alpha P H - m H$

# %% [markdown]
# ### **Question 1 :**
# <img src="../input/r_function.png" width="60%">
#
# ### **1.a)**
#
# $r(H)$ apparaît dans le modèle comme une fonction de $H$ (pop d'herbivores). Multipliée par $P$ elle constitue l'influence nette de la population d'herbivores sur la croissance des plantes. Elle constitue donc un facteur déterminant dans la croissance de la population de plantes $P$. $P$ module donc les effets de $r(H)$. $r(H)$ prise uniquement représente donc les effets sur $P$ pour une population de plantes $P$ par défaut en fonction de $H$.
# Nous allons distinguer les différentes caractéristiques de $r(H)$ et les expliquer une par une.
#
# - $r(0)$ est strictement positive, c'est nécessaire pour modéliser la croissance des plantes en l'absence d'herbibores
# - $r$ est croissante car selon l'énoncé, une certaine quantité d'herbivores donne un taux de croissance plus élevé que pas dutout d'herbivores, il existe donc forcément des valeurs $H_i$ tels que $r(H_i) > r(0)$ et d'après l'énoncé l'inégalité est stricte
# - D'après l'énoncé, une trop grande population d'herbivores aurait un impact négatif sur la croissance des plantes, donc nécessairement, à partir d'un certain $H$, $r$ devient et reste négative, par continuité la fonction est forcément décroissante à partir d'un $H$. Comme $r$ est d'abord croissante puis décroissante, elle atteint un maximum en un point que l'on peut appeler $H_m$.
# - Pour la forme parabolique, je sais pas justifier.

# %% [markdown]
# ### **1.b)**
#
# Dans la suite on considère $r(H) = r(0)(1+\frac{H}{\beta})(1-\frac{H}{\gamma})$
#
# Pour que la fonction $r$ soit de la bonne forme, il faut d'abord :
# - $r(0), \beta, \gamma > 0$
#
# Ensuite, on considère la dérivée par rapport à $H$ de $r$, on a :
# $r'(H) = \frac{r(0)}{\beta\gamma}[\gamma - \beta - 2H]$
#
# $ r'(H) = 0 \Leftrightarrow H = \frac{\gamma - \beta}{2}$
#
# Si on impose que ce point soit dans les H **strictement** positifs (ce qui  est notre cas), on a la condition $\gamma > \beta$
#
# On a donc :
# - $H_m = \frac{\gamma - \beta}{2}$
# - $r(H_m) = r(0)\frac{(\gamma + \beta)^2}{4\gamma\beta}$

# %% [markdown]
# ### **Question 2 - Adimensionnalisation**
#
# On considère le système initial:
#
# \[
# \begin{cases}
# \dot{P} = r(H)P - \delta P^2 \\
# \dot{H} = \alpha P H - m H
# \end{cases}
# \]
#
# On cherche des changements de variables pour obtenir un système de la forme :
#
# $$
# \begin{cases}
# \dot{P} = r(H)P - \delta P^2 \\
# \dot{H} = P H - H
# \end{cases}
# $$
#
# On pose les variables sans dimension :
#
# $$
# \begin{aligned}
# &x = k_1P, \qquad y = k_2H, \qquad \tau = k_3 t .
# \end{aligned}
# $$
#
# **Calcul de $\dfrac{dx}{d\tau}$**
#
# - Développement :
#
# $$
# \begin{aligned}
# &\frac{dx}{d\tau}
# = \frac{d(k_1P)}{d(k_3t)}
# = \frac{k_1}{k_3}\frac{dP}{dt} \\
# &= \frac{k_1}{k_3}(r(H)P-\delta P^2) \\
# &= \frac{k_1}{k_3}\Bigl[r\!\Bigl(\frac{y}{k_2}\Bigr)\frac{x}{k_1}
# - \delta\Bigl(\frac{x}{k_1}\Bigr)^2\Bigr] \\
# &= \frac{1}{k_3}\Bigl[r\!\Bigl(\frac{y}{k_2}\Bigr)\,x
# - \Bigl(\frac{\delta}{k_1}\Bigr) x^2\Bigr].
# \end{aligned}
# $$
#
# - Donc :
#
# $$
# \begin{aligned}
# &\frac{dx}{d\tau} = \frac{1}{k_3}\Bigl[r\!\Bigl(\frac{y}{k_2}\Bigr)\,x
# - \Bigl(\frac{\delta}{k_1}\Bigr) x^2\Bigr].
# \end{aligned}
# $$
#
# **Calcul de $\dfrac{dy}{d\tau}$**
#
# - Développement :
#
# $$
# \begin{aligned}
# &\frac{dy}{d\tau}
# = \frac{d(k_2H)}{d(k_3t)}
# = \frac{k_2}{k_3}\frac{dH}{dt} \\
# &= \frac{k_2}{k_3}(\alpha PH-mH) \\
# &= \frac{k_2}{k_3}\Bigl[\alpha \frac{x}{k_1}\frac{y}{k_2}
# - m\frac{y}{k_2}\Bigr] \\
# &= \frac{1}{k_3}\Bigl[\frac{\alpha}{k_1}xy-my\Bigr].
# \end{aligned}
# $$
#
# On pose $k_3 = m$ et $k_1 = \alpha/m$, alors :
#
# $$
# \begin{aligned}
# &\frac{dy}{d\tau}
# = \frac{1}{m}\Bigl[\frac{\alpha}{\alpha/m}xy-my\Bigr]
# = xy-y.
# \end{aligned}
# $$
#
# On réinjecte $k_3=m$ et $k_1=\alpha/m$ dans l’expression de $\dfrac{dx}{d\tau}$ :
#
# $$
# \begin{aligned}
# &\frac{dx}{d\tau}
# = \frac{1}{m}\Bigl[r\!\Bigl(\frac{y}{k_2}\Bigr)\,x
# - \frac{\delta}{\alpha/m}x^2\Bigr] \\
# &= \frac{1}{m}r\!\Bigl(\frac{y}{k_2}\Bigr)\,x
# - \frac{\delta}{\alpha}x^2.
# \end{aligned}
# $$
# On peut conserver $\delta = \frac{\delta}{\alpha}$ sans conséquence car $\alpha$ positif et $\delta$ non fixé.
# En posant $r_1(z)=\frac{1}{m}r(z)$ et $k_2=1$, on obtient :
#
# $$
# \begin{aligned}
# &\frac{dx}{d\tau} = r_1(y)x - \delta x^2, \\
# &\frac{dy}{d\tau} = xy - y.
# \end{aligned}
# $$
#
# Finalement, en renommant les variables, le système adimensionnalisé est de la forme :
#
# $$
# \begin{cases}
# \dot{P} = r_1(H)P - \delta P^2, \\
# \dot{H} = PH - H,
# \end{cases}
# $$
#
# avec $r_1(H) = \frac{1}{m}r(H)$.
#
# Dans la suite, on pourra noter $r_1(H)$ comme $r(H)$ sans ambiguïté, étant donné que le scaling $\frac{1}{m}$ est absorbé par r0 qui n'est jamais fixé.

# %%
using Plots
#Définition des variables,fonctions pour plus tard

#CONSTANTES
r0 = 1
β = 1/6
γ = 1

function r(H)
   return r0 * ( 1 + H / β ) * ( 1 - H / γ )
end

function model_adim(P,H, δ=1)
    return [r(H) * P - δ * P^2 ; P * H - H]
end
# Out:
# model_adim (generic function with 2 methods)

# %% [markdown]
# ### **Question 3 - Isoclines nulles**
#
# Regardons les isoclines nulles de
# $$
# \begin{cases}
# \dot{P} = r(H)P - \delta P^2 \\
# \dot{H} = PH - H
# \end{cases}
# $$
#
# **Isocline $\dot{P} = 0$** :
# $$
# r(H)P - \delta P^2 = 0 \quad \Rightarrow \quad P \bigl( r(H) - \delta P \bigr) = 0
# $$
# - Soit $P = 0$
# - Soit $P = \frac{r(H)}{\delta}$

# %%
H_range = 0:0.01:2

####################################
# 1) Fenêtre pour l'isocline P' = 0
####################################
iso_P1 = [(h, r(h)) for h in H_range if r(h) ≥ 0]   # P = r(H)
iso_P2 = [(h, 0.0)   for h in H_range]              # P = 0

pP = plot(
    xlabel = "H", ylabel = "P",
    title = "Isoclines P' = 0",
    xlims = (0, 2), ylims = (0, 2.5),
    legend = false,
    grid = true
)

# P = r(H)
plot!(pP,
    first.(iso_P1), last.(iso_P1),
    color = :blue, linewidth = 3,
)

# P = 0
plot!(pP,
    first.(iso_P2), last.(iso_P2),
    color = :blue, linewidth = 3,
)

display(pP)

# %% [markdown]
# **Isocline $\dot{H} = 0$** :
# $$
# PH - H = 0 \quad \Rightarrow \quad H(P - 1) = 0
# $$
# - Soit $H = 0$
# - Soit $P = 1$

# %%
P_range = 0:0.01:2

####################################
# 2) Fenêtre pour les isoclines H' = 0
####################################
iso_H1 = [(p, 1.0) for p in P_range]    # H = 0
iso_H2 = [(0, p) for p in P_range]   # P = 1

pH = plot(
    xlabel = "H", ylabel = "P",
    title = "Isoclines H' = 0",
    legend = false, grid = true,
    xlims = (0, 2), ylims = (0, 2),
)

# H = 0 (axe horizontal)
plot!(pH,
    first.(iso_H1), last.(iso_H1),
    color = :red, linewidth = 3,
)

# P = 1 (droite verticale)
plot!(pH,
    first.(iso_H2), last.(iso_H2),
    color = :red, linewidth = 3,
)

display(pH)

# %% [markdown]
# Il y a 3 configurations d'équilibres

# %%
using Plots

# Ranges pour le tracé
H_range = 0:0.01:1.2
P_range = 0:0.01:2.5

# Isoclines H' = 0 (Rouges)
iso_H1 = [(p, 1.0) for p in P_range]    # P = 1
iso_H2 = [(0.0, p) for p in P_range]    # H = 0

iso_P2 = [(h, 0.0) for h in H_range]    # P = 0

# 4 Valeurs de δ (le max de r(H) est rm = 1.125)
delta_cases = [
    2.5,    # Cas 1 : r_m/δ < 1 (0 équilibre interne)
    51/25,  # Cas 2 (Critique) : r_m/δ = 1 (tangent, 1 éq. double)
    1.5,   # Cas 3 : r_0/δ < 1 < r_m/δ (2 éq. int.)
    0.95    # Cas 4 : 1 < r_0/δ (1 éq. int.)
]

titles = [
    "Cas 1", 
    "Cas 2", 
    "Cas 3", 
    "Cas 4"
]

for (i, δ) in enumerate(delta_cases)
    
    p = plot(
        xlabel = "H", ylabel = "P",
        title = titles[i],
        xlims = (0, 1.1), ylims = (0, 2.5),
        legend = false,
        grid = true
    )
    
    iso_P1 = [(h, r(h)/δ) for h in H_range if r(h) ≥ 0] # P = r(H)/δ

    # Trace Isoclines P' = 0
    plot!(p, first.(iso_P1), last.(iso_P1), color = :blue, linewidth = 3)
    plot!(p, first.(iso_P2), last.(iso_P2), color = :blue, linewidth = 3)
    
    # Trace Isoclines H' = 0
    plot!(p, first.(iso_H1), last.(iso_H1), color = :red, linewidth = 3)
    plot!(p, first.(iso_H2), last.(iso_H2), color = :red, linewidth = 3)
    
    display(p)
end

# %% [markdown]
# ## Analyse :
# 4 cas semblent se distinguer, parmis ces 4 cas on en considèrera 3 comme générique et la raison de cela est détaillée dans cette cellule.
#
# On peut distinguer ces 3 cas en fonction de la position de la parabole bleue définie par $P(H)$ vis à vis de la constante définie par $P = 1$.
#
# Or cette fameuse parabole est définie par $P(H) = \frac{r(H)}{\delta}$.
#
# De par la forme de $r$ on peut déterminer les conditions sur $\delta$ afin d'obtenir les différents cas visualisés plus haut:
# - cas 1 :
#     La courbe de $P(H)$ est en dessous de $P=1$ sur $\mathbb{R}_+$
#     C'est à dire $\frac{r(H)}{\delta} < 1$ sur $\mathbb{R}_+$
#     Or $r(H)$ est maximum en $H_m$
#     Au final il faut vérifier : $\frac{r(H_m)}{\delta} < 1$
#     En remplaçant $r$ par son expression et en isolant $\delta$ on obtient finalement comme condition:
#     $\delta > \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) = \frac{49}{24}r(0)$
#
# - cas 3 :
#     Le cas 2 est défini par la courbe de $P(H)$ coupant 2 fois $P = 1$
#     Dans ce cas, en son maximum :
#     $\frac{r(H)}{\delta} > 1$ (On renverse la condition du cas précédent)
#     C'est à dire : $\delta < \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0)$
#     Et on a de plus, en $H = 0$, $P(H) < 1$
#     Donc $\frac{r(0)}{\delta} > 1$
#     C'est à dire :  $\delta > r(0)$
#     Pour résummer, on doit avoir :
#     $ \delta < \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) = \frac{49}{24}r(0) $
#     ET
#     $ \delta > r(0)  $
#
# - cas 4 :
#     Graphiquement, le cas 3 vérifie  :
#     la courbe de $P(H)$ est au-dessus de $P = 1$ au moins sur $\lceil 0, H_m \rceil$
#     Commme $r$ atteint son maximum en $H_m$ il suffit juste de vérifier :
#     $P(H=0) > 1$ et cette condition est vérifiée pour $ \delta < r(0) $
#
# - cas non générique (cas 2) :
#     Celui-ci correspond au cas où la courbe de $P(H)$ est en-dessous celle de $P = 1$ excepté en un point où ces courbes se croisent, nécéssairement au point où
#     $P(H)$ atteint son maximum c'est à dire en $H_m$.
#     De par la forme de $P(H)$ (parabole avec coefficient quadratique négatif) la seule condition à vérifier est :
#     $P(H_m) = 1$
#     Elle est vérifiée en : $\delta = \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) $
#     Or une condition de stricte égalité sur $\delta$ est largement improbable, on ne la considère pas comme cas générique.
#
# Le cas 2 n'étant pas un cas générique, nous ne le considèrerons pas pour les analyses futures.
#
# ## Définition des équilibres
# Procédons au recensement des équilibres en fonction des cas.
# On nommera les équilibres positifs, les équilibres atteints lorsque les valeurs de $H$ et $P$ sont distinctes de 0, tel que convenu dans le sujet.
# - cas 1 :
#     - Les 2 courbes vivant dans l'espace positif ne se croisent jamais, ainsi pas d'équilibre positif : $H_1^*$ et $H_2^*$ n'existent pas.
#     - On a tout de même 2 équilibres en $(P,H)=(0,0)$ et en  $(P,H)=(P(H=0),0)$
#
# - cas 3 :
#     - Les 2 courbes vivant dans l'espace positif se croisent deux fois :
#         - une fois en  $(P,H)=(P(H_1),H_1)$ avec $H_1 < H_m$ ainsi on appellera cet équilibre en $H$ : $H_1^*$
#         - une fois en  $(P,H)=(P(H_2),H_2)$ avec $H_2 > H_m$ ainsi on appellera cet équilibre en $H$ : $H_2^*$
#
# - cas 4 :
#     - Les 2 courbes vivant dans l'espace positif ne se croisent qu'une seule fois, en $(P,H)=(P(H),H)$ avec $H > H_m$ ainsi on appellera cet équilibre en $H$ : $H_2^*$
#     - On conserve les 2 équilibres récurrents en $(P,H)=(0,0)$ et en  $(P,H)=(P(H=0),0)$

# %% [markdown]
# ### **Question 4 - Jacobienne**
#
# on a $J(P,H) =
# \begin{pmatrix}
# r(H) - 2\delta P & P r'(H) \\
# H & P - 1
# \end{pmatrix}$
#
# Pour chaque cas, on évalue la jacobienne en chacun des équilibres en espérant obtenir des informations sur la stabilité de ceux-ci grâce au théorème de Lyapunov indirect.
#
# **Rappels sur Lyapunov indirect :**
# On évalue la jacobienne liée au système pour chaque équilibre $X^* = (P^*,H^*)$, et :
# - si toutes les valeurs propres de $Jac(X^*)$ sont à partie réelle négative alors $X^*$ est un équilibre asymptotiquement stable (ASS) ie :
#         si $\forall i,\ \operatorname{Re}(\lambda_i) < 0\ \text{avec}\ \lambda_i \in \sigma(Jac(X^*)) \implies X^*\ \text{asymptotiquement stable}$
# - s'il existe une valeur propre de $Jac(X^*)$ à partie réelle strictement positive alors $X^*$ est instable ie :
#         si $\exists i, \ \operatorname{Re}(\lambda_i) > 0\ \text{avec}\ \lambda_i \in \sigma(Jac(X^*)) \implies X^*\ \text{instable}$
# - si toutes les parties réelles des valeurs sont négatives à l'exception de certaines qui sont égales à 0, on ne peut pas conclure ie :
#  si $\exists i, \ \operatorname{Re}(\lambda_i)=0\ \text{et}\ \forall j\neq i,\ \operatorname{Re}(\lambda_j)<0 \quad \implies \quad \text{stabilité de } X^* \text{ indéterminée}$

# %% [markdown]
# - ###  Equilibres en présence agnostique aux cas :
# On note 2 équilibres, en (P,H) respectivement :
#     - en $(0,0)$
#     - en $(\frac{r(0)}{\delta},0)$
#
# Peu importe le cas étudié (1,3 ou 4), ces équilbres sont présents dans le système, déterminons leur stabilité.
#
#
#
# - Pour $(0,0)$ :
# $J(0,0) =
# \begin{pmatrix}
# r(0) & 0 \\
# 0 & -1
# \end{pmatrix}$
# Les valeurs propres sont $r(0)$ et $-1$ or $r(0) \in \mathbb{R_+^*}$ donc $\operatorname{Re}(r(0)) > 0$, ainsi $(0,0)$ est instable.
#
# - Pour  $(\frac{r(0)}{\delta},0)$ :
# $J(\frac{r(0)}{\delta},0) =
# \begin{pmatrix}
# -r(0) & \frac{1}{\delta} r(0) r'(0) \\
# 0 & \frac{r(0)}{\delta}-1
# \end{pmatrix}$
# Les valeurs propres d'une matrice triangulaire supérieure sont également les termes sur la diagonale.
# On pose :
# $\lambda_1 = -r(0)$ et $\lambda_2 = \frac{r(0)}{\delta}-1$
# Donc si $\operatorname{Re}(\lambda_1)$ et $\operatorname{Re}(\lambda_2)$ sont toutes 2 inférieures à 0, on a stabilité de  $(\frac{r(0)}{\delta},0)$.
# Déterminons les différents cas qui découlent de cette assertion.
# Par définition $r(0)$ est positif donc $\operatorname{Re}(\lambda_1)<0$.
# Et $\operatorname{Re}(\lambda_2)<0 \iff \lambda_2 <0\iff \frac{r(0)}{\delta}-1 < 0 \iff \delta > r(0) $
# Cette condition est vérifiée dans les cas 1 et 3.
# C'est à dire dans le cas 1 et le cas 3, $(\frac{r(0)}{\delta},0)$ est asymptotiquement stable.
# En revanche, dans le cas 4, $(\frac{r(0)}{\delta},0)$ est instable.

# %% [markdown]
# - #### Equilibres au cas par cas
#
# - cas 3 : présence de 2 équilibres positifs
# On évalue la jacobienne en $H_1^*$ et en $H_2^*$
# En ces équilibres, P vaut nécessairement 1 (cf graphs précédents) donc $P(H_1^*) = P(H_2^*) = 1$
# - Pour $(P(H_1^*),H_1^*)$ :
# $J(P(H_1^*),H_1^*) =
# \begin{pmatrix}
# r(H_1^*) - 2\delta P(H_1^*) & P(H_1^*) r'(H_1^*) \\
# H_1^* & P(H_1^*) - 1
# \end{pmatrix}    =
# \begin{pmatrix}
# r(H_1^*) - 2\delta &  r'(H_1^*) \\
# H_1^* & 0
# \end{pmatrix} =
# \begin{pmatrix}
# -\delta &  r'(H_1^*) \\
# H_1^* & 0
# \end{pmatrix}
# $

# %% [markdown]
# ### Rappel sur un critère de convergence
# En plaçant sur un plan le determinant de la jacobienne évaluée aux points d'équilibres et la trace évaluée en ces mêmes points, on peut être en capacité de définir les types de stabilité et d'instabilité de ces équilibres.

# %% [markdown]
# ![Critère de stabilité](../input/crit_stab.png)

# %% [markdown]
# Or,
# $det[J(P(H_1^*),H_1^*)] = - H_1^* r'(H_1^*)$
# Or en $H_1^*$ équilibre positif atteint avant le max de $r$, on a $r$ croissante car parabole concave donc :
# $r'(H_1^*) > 0 ⟹ det[J(P(H_1^*),H_1^*)] < 0$
# Donc ici, $(tr[J(P(H_1^*),H_1^*)], det[J(P(H_1^*),H_1^*)])$ est dans la zone de point selle (instable).

# %% [markdown]
# - Pour $(P(H_2^*),H_2^*)$ :
# $J(P(H_2^*),H_2^*) =
# \begin{pmatrix}
# r(H_2^*) - 2\delta P(H_2^*) & P(H_2^*) r'(H_2^*) \\
# H_2^* & P(H_2^*) - 1
# \end{pmatrix}   =
# \begin{pmatrix}
# P(H_2^*)\delta - 2\delta &  r'(H_2^*) \\
# H_2^* & 0
# \end{pmatrix} =
# \begin{pmatrix}
# -\delta &  r'(H_2^*) \\
# H_2^* & 0
# \end{pmatrix}
# $
# Donc $tr(J(P(H_2^*),H_2^*)) = -\delta < 0$
# et $det(J(P(H_2^*),H_2^*)) = -H_2^* r'(H_2^*)$
# Or $h_2^*$ équilibre positif et $r'(H-2^*)$ dérivée d'une parabole concave post-maximum nécessairement négative donc :
# $det(J(P(H_2^*),H_2^*)) > 0$
# Au final $(tr[J(P(H_2^*),H_2^*)], det[J(P(H_2^*),H_2^*)])$ se trouve dans le quart nord-est du graph, stable !

# %% [markdown]
# ### Conclusion
# Peu importe le cas, tant qu'il y a existence de ces équilibres :
# * $(0,0)$ est instable
# * $(\frac{r(0)}{\delta}, 0)$ est ASS dans le cas 1 et 3 et instable dans le 4e cas
# * $(P(H_1^*), H_1^*)$ est toujours instable
# * $(P(H_2^*), H_2^*)$ est toujours ASS

# %% [markdown]
# ### **Question 5 - Diagramme de Bifurcation**
# Pour rappel on a :
#
# - cas 1 :
#     $\frac{r(H_m)}{\delta} < 1$
#
#     $\delta > \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0)$
#
#
# - cas 3 : $\delta > r(0)$
#
#     $ \delta < \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0)$
#     ET
#     $ \delta > r(0)  $
#
#
# - cas 4 : $P(H=0) > 1$
#
#     $ \delta < r(0) $

# %% [markdown]
# ### Tout d'abord, on a $\frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) > r0$.
#
# En effet, on a $(\frac{(\gamma + \beta)^2}{4\gamma\beta} > 1) \Leftrightarrow ( (\gamma + \beta)^2 > 4\gamma\beta )$
#
# En développant on obtient $(\gamma^2 + 2\gamma\beta + \beta^2 > 4 \gamma\beta) \Leftrightarrow (\gamma^2 - 2\gamma\beta + \beta^2 > 0)$
#
# En remarquant que $\gamma^2 - 2\gamma\beta + \beta^2 = (\gamma - \beta)^2$, on a donc $$(\frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) > r0) \Leftrightarrow ((\gamma - \beta)^2 > 0),$$
# ce qui est toujours vrai.
#
#
# Dans la suite on va donc étudier les équilibres dans les cas suivants : $\delta \in [0, r(0)]$, $\delta \in [r(0), \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0)]$, $\delta \in [\frac{(\gamma + \beta)^2}{4\gamma\beta}r(0), +\infty[$ qui correspondent respectivement aux cas 4, cas 3, et cas 1.

# %% [markdown]
# ### On considère d'abord le segment $[0, r(0)]$ :
#
# <img src="data:image/png;base64,..." />
#
# À l'équilibre non trivial, on a
# $$
# r(H^*) = \delta
# $$
#
# En utilisant l'expression générale de $r(H)$ donnée par :
# $$
# r(H) = r(0) \left(1 + \frac{H}{\beta}\right) \left(1 - \frac{H}{\gamma}\right)
# $$
#
# L'équation devient :
# $$
# r(0) \left( 1 - \frac{H^*}{\gamma} + \frac{H^*}{\beta} - \frac{(H^*)^2}{\beta\gamma} \right) = \delta
# $$
#
# On obtient une équation du second degré en $H^*$:
# $$
# -\frac{1}{\gamma\beta}{H^*}^2 + {H^*}(\frac{1}{\beta} - \frac{1}{\gamma}) + 1 - \frac{\delta}{r(0)} = 0
# $$
# $$
# \Leftrightarrow
# $$
# $$
# {H^*}^2 - (\gamma - \beta)H^* - \beta\gamma \left( 1 - \frac{\delta}{r(0)} \right) = 0
# $$
#
# Calculons le discriminant $\Delta$ de ce polynôme :
# $$
# \Delta = (\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)
# $$
#
# Par hypothèse, nous avons par hypothèse $\delta \leq r(0)$, ce qui implique que le terme $\left( 1 - \frac{\delta}{r(0)} \right)$ est positif ou nul.
#
# Par conséquent, on a toujours $\Delta > 0$ : l'équation admet deux racines réelles distinctes.
#
# On a
# $$
# H_{\pm}^* = \frac{(\gamma - \beta) \pm \sqrt{\Delta}}{2}
# $$
#
# (Pour rappel, on a $\gamma > \beta$ quel que soit le cas)
#
# Très clairement, on a $H_+ > H_-$ et les analyses précédentes nous montrent que $H_-$ est une racine négative et $H_+$ une racine positive.
#
# Les densités de population doivent être positives ou nulles ($H \geq 0$), donc l'expression de cet équilibre que l'on nomme $H_2^*$ en fonction de $\delta$ est la suivante :
# $$
# H_2^*(\delta) = \frac{(\gamma - \beta) + \sqrt{(\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)}}{2}
# $$
#
# ### Analyse qualitative
#
# *   **Limite quand ($\delta \to 0^+$) :** par continuité on a égalité avec
#     $$
#     H_2^*(0) = \frac{(\gamma - \beta) + \sqrt{(\gamma - \beta)^2 + 4\beta\gamma}}{2}
#     $$
#     En remarquant que $(\gamma - \beta)^2 + 4\beta\gamma = (\gamma + \beta)^2$, on obtient :
#     $$
#     H_2^*(0) = \frac{(\gamma - \beta) + (\gamma + \beta)}{2} = \gamma
#     $$
#
# *   **Limite quand ($\delta \to r(0)^-$) :** par continuité on a égalité avec
#     $$
#     H_2^*(r(0)) = \frac{(\gamma - \beta) + \sqrt{(\gamma - \beta)^2}}{2}
#     $$
#
#     $$
#     H_2^*(r(0)) = \frac{(\gamma - \beta) + (\gamma - \beta)}{2} = \gamma - \beta < \gamma
#     $$
#
# On a donc $H_2^*(\delta)$ qui vaut $\gamma$ en $0$ et qui décroit de manière concave, par composition de $ \delta \mapsto (\gamma - \beta)^2 + 4\beta\gamma ( 1 - \frac{\delta}{r(0)} )$ (linéaire décroissante) et $x \mapsto \sqrt{x}$ (concave croissante), jusqu'a atteindre $\gamma - \beta$ en $r(0)$

# %% [markdown]
# ### On considère maintenant le segment $[r(0), \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0)] = [r(0), r(H_m)]$
#
# <img src="data:image/png;base64,..." />
#
# On se ramène à la même équation que précedemment, mais cette fois on a $\delta > r(0)$, on sait cependant que il y a deux équilibres positifs donc on peut supposer $\Delta$ positif
#
# $$
# H_{\pm}^* = \frac{(\gamma - \beta) \pm \sqrt{\Delta}}{2}
# $$
#
# avec
# $$
# \Delta = (\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)
# $$
#
# On va se référer à $H_-^*$ en tant que $H_1^*$ et $H_+^*$ comme $H_2^*$ on sait que ces deux se rejoignent en $H_m = \frac{\gamma - \beta}{2}$
#
# Analysons ces équilibres :
#
# - $H_1^*(\delta) = \frac{(\gamma - \beta) - \sqrt{(\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)}}{2}$
# On a d'une part $H_1^*(r(0)) = \frac{(\gamma - \beta) - (\gamma - \beta)}{2} = 0 $ \
# D'autre part, on cherche pour quel $\delta$ on a $H_1^*(\delta)$ qui vaut $H_m$, on résout alors :
# $$
# \frac{(\gamma - \beta) - \sqrt{(\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)}}{2} = H_m = \frac{\gamma - \beta}{2}
# $$
# Ce qui revient bien à annuler $\Delta$ \
# En résolvant l'équation, on obtient $\delta = r(0)(1 + \frac{(\gamma - \beta)^2}{4\gamma\beta}) = r(0)\frac{(\gamma + \beta)^2}{4\gamma\beta} = r(H_m)$
# Ce qui est cohérant, car cela revient au cas où $\frac{r(H_m)}{\delta} = 1$ \
# On en conclut que $H_1^*(r(0)) = 0$ et par des arguments similaires au cas précédent (continuité, composition...), $H_1^*$ est croissante de manière convexe jusqu'a atteindre $\frac{\gamma - \beta}{2}$ en $r(H_m)$
#
#
#
#
# - $H_2^*(\delta) = \frac{(\gamma - \beta) + \sqrt{(\gamma - \beta)^2 + 4\beta\gamma \left( 1 - \frac{\delta}{r(0)} \right)}}{2}$ \
# On a $H_2^*(r(0)) = \frac{(\gamma - \beta) + (\gamma - \beta)}{2} = \gamma - \beta > H_m = \frac{\gamma - \beta}{2}$
#
# $H_2^*$ vaut $\gamma - \beta$ en $r(0)$ et est décroissante de manière concave jusqu'a atteindre $H_m = \frac{\gamma - \beta}{2}$

# %% [markdown]
# ### On considère maintenant $[\frac{(\gamma + \beta)^2}{4\gamma\beta}r(0), +\infty[ = [r(H_m), +\infty[$
#
# <img src="data:image/png;base64,..." />
#
# Dans ce cas il n'y a pas d'équilibres non triviaux pour H, donc rien à tracer au-delà de $\delta = \frac{(\gamma + \beta)^2}{4\gamma\beta}r(0) = r(H_m)$

# %%
# Calcul du maximum de r(H) pour les limites du tracé
Hm = (γ - β) / 2
r_max = r(Hm)

# Fonctions définissant les branches d'équilibres H*
function H1_star(δ)
    return ((γ - β) - sqrt((γ - β)^2 + 4 * β * γ * (1 - δ / r0))) / 2
end

function H2_star(δ)
    return ((γ - β) + sqrt((γ - β)^2 + 4 * β * γ * (1 - δ / r0))) / 2
end

# Création des vecteurs de données pour delta
delta_cas4 = range(0.01, r0, length=150)
delta_cas3 = range(r0, r_max, length=150)

# On choisit les valeurs numériques à marquer, et on leur associe un texte
valeurs_x = [0.0, r0, r_max]
labels_x = ["0", "r(0)", "r_max"]

valeurs_y = [0.0, Hm, γ - β, γ]
labels_y = ["0", "H_m", "γ - β", "γ"]

# Tracé du diagramme complet avec xticks et yticks
p_bifurcation = plot(
    xlabel="Paramètreδ", 
    ylabel="Équilibres H*",
    title="Diagramme de bifurcation de H* en fonction de δ",
    grid=true,
    framestyle=:box,
    legend=:bottomleft,
    xlims=(0, r_max + 0.1),
    ylims=(-0.1, γ + 0.1),
    xticks=(valeurs_x, labels_x), # On remplace les graduations par les lettres
    yticks=(valeurs_y, labels_y)  # Pareil pour l'axe Y
)

# -- Cas 4 : Branche H2*
plot!(p_bifurcation, delta_cas4, H2_star.(delta_cas4), 
      label="H₂* (Cas 4 : δ ≤ r₀)", color=:darkgreen, linewidth=2.5)

# -- Cas 3 : Branche H2*
plot!(p_bifurcation, delta_cas3, H2_star.(delta_cas3), 
      label="H₂* (Cas 3 : r₀ < δ ≤ r_max)", color=:limegreen, linewidth=2.5)

# -- Cas 3 : Branche H1* 
plot!(p_bifurcation, delta_cas3, H1_star.(delta_cas3), 
      label="H₁* instable (Cas 3)", color=:red, linestyle=:dash, linewidth=2.5)


# Ajout des points d'intérêt
scatter!(p_bifurcation, [r0], [0.0], color=:magenta, markersize=5, label="Bifurcation Transcritique")
scatter!(p_bifurcation, [r_max], [Hm], color=:black, markersize=5, label="Bifurcation Nœud-Col")
# Point de départ sur l'axe des ordonnées

display(p_bifurcation)

# %% [markdown]
# ### **Question 6 - Plan de Phase**

# %%
# Importation des librairies nécessaires
using Plots
using LinearAlgebra
# Si DifferentialEquations n'est pas installé, lancez `import Pkg; Pkg.add("DifferentialEquations")`
using DifferentialEquations 

# Constantes du modèle
r0 = 1.0
β = 1/6
γ = 1.0
Hm = (γ - β)/2
r_max = r0 * (1 + Hm / β) * (1 - Hm / γ)

# Fonction r(H)
function r(H)
   return r0 * (1 + H / β) * (1 - H / γ)
end

# Système dynamique pour la résolution de trajectoire (ODE)
function system!(du, u, p, t)
    P, H = u
    δ = p[1]
    
    # Sécurité numérique : on empêche les populations de devenir négatives lors de l'intégration
    P = max(0.0, P)
    H = max(0.0, H)
    
    du[1] = r(H) * P - δ * P^2
    du[2] = P * H - H
end

# Fonction maîtresse qui dessine le plan de phase selon le delta donné
function plot_phase_portrait(δ, title_str)
    # 1. Configuration des limites du graphique
    P_max = max(2.0, r(0)/δ + 0.5)
    H_max = γ + 0.3
    
    P_range = range(0, P_max, length=150)
    H_range = range(0, H_max, length=150)
    
    plt = plot(title=title_str, xlabel="Plantes (P)", ylabel="Herbivores (H)", 
               xlims=(-0.1, P_max), ylims=(-0.1, H_max), legend=:outertopright, size=(700, 500))
    
    # 2. Isoclines nulles
    # Isoclines dP/dt = 0 (Bleu) : P = 0 et P = r(H)/δ
    P_iso1 = [r(h)/δ for h in H_range]
    plot!(plt, P_iso1, H_range, color=:blue, label="Isocline dP/dt=0 (P=r(H)/δ)", linewidth=2)
    plot!(plt, [0.0, 0.0], [0.0, H_max], color=:blue, label="", linewidth=2)
    
    # Isoclines dH/dt = 0 (Rouge) : H = 0 et P = 1
    plot!(plt, [0.0, P_max], [0.0, 0.0], color=:red, label="Isocline dH/dt=0 (H=0)", linewidth=2)
    plot!(plt, [1.0, 1.0], [0.0, H_max], color=:red, label="Isocline dH/dt=0 (P=1)", linewidth=2)
    
    # 3. Champ de vecteurs (Quiver)
    n_arrows = 18
    P_arrows = range(0.1, P_max-0.1, length=n_arrows)
    H_arrows = range(0.1, H_max-0.1, length=n_arrows)
    
    pts = [(p, h) for p in P_arrows for h in H_arrows]
    u_vec = zeros(2)
    vecs = []
    
    for pt in pts
        system!(u_vec, [pt[1], pt[2]], [δ], 0.0)
        norm_v = norm(u_vec)
        if norm_v > 0
            # On norme les vecteurs pour avoir des flèches de taille constante (0.05)
            u_norm = u_vec ./ norm_v * 0.05 
            push!(vecs, (u_norm[1], u_norm[2]))
        else
            push!(vecs, (0.0, 0.0))
        end
    end
    # quiver de Plots nécessite deux tableaux séparés pour X et Y
    u_vals = [v[1] for v in vecs]
    v_vals = [v[2] for v in vecs]
    quiver!(plt, [pt[1] for pt in pts], [pt[2] for pt in pts], quiver=(u_vals, v_vals), color=:gray, alpha=0.5, label="Champ de vecteurs")
    
    # 4. Équilibres et Trajectoires
    # Équilibre trivial (0,0) - toujours instable (rond blanc avec contour)
    scatter!(plt, [0.0], [0.0], color=:white, markershape=:circle, markerstrokecolor=:black, markersize=7, label="Éq. instable")
    
    # Équilibre de bord (r(0)/δ, 0)
    P_semi = r0/δ
    if δ > r0 # Si delta > r(0), cet équilibre est Stable (ASS)
        scatter!(plt, [P_semi], [0.0], color=:black, markershape=:circle, markersize=7, label="Éq. ASS (Stable)")
        # Trajectoire convergente vers cet équilibre
        prob = ODEProblem(system!, [0.2, 1.2], (0.0, 100.0), [δ])
        sol = solve(prob, Tsit5())
        plot!(plt, sol, vars=(1,2), color=:darkorange, label="Trajectoire", linewidth=2.0)
    else # Sinon il est instable
        scatter!(plt, [P_semi], [0.0], color=:white, markershape=:circle, markerstrokecolor=:black, markersize=7, label="")
    end
    
    # Équilibres internes
    if δ < r_max
        # H1* (instable - col)
        H1 = ((γ - β) - sqrt((γ - β)^2 + 4*β*γ*(1 - δ/r0))) / 2
        if H1 > 0
            scatter!(plt, [1.0], [H1], color=:white, markershape=:circle, markerstrokecolor=:black, markersize=7, label="")
        end
        
        # H2* (ASS)
        H2 = ((γ - β) + sqrt((γ - β)^2 + 4*β*γ*(1 - δ/r0))) / 2
        if H2 > 0
            scatter!(plt, [1.0], [H2], color=:black, markershape=:circle, markersize=7, label="")
            
            # Trajectoire convergente vers H2*
            prob1 = ODEProblem(system!, [0.1, H2 + 0.1], (0.0, 100.0), [δ])
            sol1 = solve(prob1, Tsit5())
            plot!(plt, sol1, vars=(1,2), color=:darkorange, label= (δ > r0 ? "" : "Trajectoire"), linewidth=2.0)
            
            # Une deuxième trajectoire pour faire joli et bien montrer l'attracteur
            prob2 = ODEProblem(system!, [P_max - 0.2, 0.05], (0.0, 100.0), [δ])
            sol2 = solve(prob2, Tsit5())
            plot!(plt, sol2, vars=(1,2), color=:darkorange, label="", linewidth=2.0)
        end
    end
    
    return plt
end

# 5. Affichage des 3 plans de phase demandés
# Cas 1 : δ > r_max (Pas d'équilibre interne, les plantes dominent)
plot1 = plot_phase_portrait(2.5, "Cas 1 : δ > r_max (ex: δ = 2.5)")
display(plot1)

# Cas 3 : r0 < δ < r_max (2 équilibres internes)
plot3 = plot_phase_portrait(1.4, "Cas 3 : r(0) < δ < r_max (ex: δ = 1.4)")
display(plot3)

# Cas 4 : δ < r0 (1 seul équilibre interne)
plot4 = plot_phase_portrait(0.7, "Cas 4 : δ < r(0) (ex: δ = 0.7)")
display(plot4)
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/home/gagik/.julia/compiled/v1.12/BoundaryValueDiffEqFIRK/ughQx_U9pnv.ji.pidfile"
# └ @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.12.1+0.x64.linux.gnu/share/julia/stdlib/v1.12/FileWatching/src/pidfile.jl:247
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/home/gagik/.julia/compiled/v1.12/BoundaryValueDiffEqMIRK/6bkfK_U9pnv.ji.pidfile"
# └ @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.12.1+0.x64.linux.gnu/share/julia/stdlib/v1.12/FileWatching/src/pidfile.jl:247
# ┌ Warning: attempting to remove probably stale pidfile
# ...

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Question 7 - Fonction de Lyapunov-LaSalle**
#
# On se place dans le cas 4 : Existence d'un unique équilibre positif $H_2^*$

# %% [markdown]
# On rappelle que dans le cadre d'un système dynamique type proies-prédateurs de la forme :
# $$
# \begin{cases}
# \dot{P} = a(P) - f(P) b(H) \\
# \dot{H} = m(P)g(H) + c(H)
# \end{cases}
# $$
# Supposons un équilibre positif $Z^* = (P^*, H^*)$ de la fonction $\dot{Z} = h(Z)$ avec $h \in C^1(M,\mathbb{R}^n)$ où M est un ouvert contenant $Z^*$.
#
# **Théorème de méthode directe de Lyapunov**
# S'il existe $V \in C^1(M,\mathbb{R}^n)$ telle que :
# 1. $V(Z^*) = 0 et V(Z) > 0 \forall Z \in{M} \backslash {Z^*}$
# et
# 2. $\dot{V} \leq 0 \forall Z \in M$
# alors $Z^*$ est stable.
# De plus si :
# 3. $\dot{V} < 0 \forall Z \in M$ alors $Z^*$ est ASS
#
#
#
# **Le lemme de Harrison donne :**
#  Si les conditions suivantes sont vérifiées :
# * m(P) strictement croissante autour de $P^*$
# * f(P) > 0 autour de $P^*$
# * b(H) strictement croissante autour de $H^*$
# * g(H) > 0 autour de $H^*$
# * m et f sont de même signe autour de $P^*$
# * b et g sont de même signe autour de $H^*$
# Alors la fonction :
# $V(P,H) = \int_{P^*}^{P}\frac{m(\tau) - m(P^*)}{f(\tau)} \,dP + \int_{H^*}^{H}\frac{b(\tau) - b(H^*)}{g(\tau)} \,dH$
# est nulle en $(P^*, H^*)$ et positive dans une boule autour de $(P^*,H^*)$
# De plus on a $\dot{V} = \frac{\partial V}{\partial P} \frac{\partial P}{\partial t} + \frac{\partial V}{\partial H} \frac{\partial H}{\partial t}$
# Ce qui est égale à  $(m(P) - m(P^*)) [\frac{a(P)}{f(P)} - \frac{a(P^*)}{f(P^*)}] +(b(H) - b(H^*)) [\frac{c(H)}{g(P)} - \frac{c(H^*)}{g(H^*)}]$
#
# **Le théorème de Harrison (surcouche au Lemme)**
# En présence des hypothèses du Lemme et :
# * $\frac{a(P)}{f(P)}$ décroisssante autour de $P^*$
# * $\frac{c(H)}{g(H)}$ décroisssante autour de $H^*$
# Dont au moins l'une de ces 2 fonctions strictement décroissante alors : $Z^*$ est asymptotiquement stable$
#
# **Le théorème d'invariance de LaSalle (surcouche au Lemme)**
# Sous les conditions 1 et 2 de Lyapunov direct
# EN FAIT INUTILE ICI JE CROIS

# %% [markdown]
# ### **7.a)**

# %% [markdown]
# ### **7.b)**

# %% [markdown]
# ### **7.c)**

# %% [markdown]
# ## **Question 8**
